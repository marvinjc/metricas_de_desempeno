# %% [markdown]
# <a href="https://colab.research.google.com/github/marvinjc/metricas_de_desempeno/blob/main/Breast_Cancer_Wisconsin_(Diagnostic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/marvinjc/metricas_de_desempeno/main/breast_cancer_wisconsin.data"

# %%
df = pd.read_csv(url, header=None)
df = df.rename(columns={0: "id", 1: "diagnostico"})

# %%
display(df.head())
# Out:
#          id diagnostico      2      3       4       5        6        7  \
# 0    842302           M  17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1    842517           M  20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2  84300903           M  19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3  84348301           M  11.42  20.38   77.58   386.1  0.14250  0.28390
# 4  84358402           M  20.29  14.34  135.10  1297.0  0.10030  0.13280
#
#         8        9  ...     22     23      24      25      26      27      28  \
# 0  0.3001  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.0869  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.1974  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.2414  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.1980  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# ...

# %%
df["diagnostico"].value_counts()
porcentaje = df["diagnostico"].value_counts(normalize=True) * 100

# %%
print(conteo)
print(porcentaje.round(2))
# Out:
# 1
# B    357
# M    212
# Name: count, dtype: int64
# diagnostico
# B    62.74
# M    37.26
# Name: proportion, dtype: float64
